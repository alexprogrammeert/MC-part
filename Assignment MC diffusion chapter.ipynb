# %%
import numpy as np

# %%
## Monte Carlo part - Group 9

# %% [markdown]
# ### Assignments chapter 2
# c: write a script that can generate trajectories for bacteria motion based on the probability distribution 2.3.

# %%
# code for 2a:
N = 10  # number of steps
r = 1   # length of displacement step
A=0.5

P= 1/(2*np.pi)*(1+A*np.cos(phi))
r_dis = r*(np.cos(phi), np.sin(phi))    # displacement vector of a step
# Out:
# (np.float64(-1.0), np.float64(1.2246467991473532e-16))
